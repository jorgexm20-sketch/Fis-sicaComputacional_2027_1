# %% [markdown]
# <h1 align="center">Física Computacional.</h1>
# <h1 align="center">Semestre 2027-1</h1>
#
# <h2>Sergio A. Alcalá Corona </h2>
#
# ---
# ### Rodrigo Vega Vilchis
# ### Joel Gómez Uribe
# ---

# %% [markdown]
# <h1 align="center">Programación para la física computacional</h1>
#
# ## Práctica 1.  Programación básica para la física
#
# En esta tarea se realizan ejercicios de python básico usado en matemáticas (cambio de coordenadas), física (relatividad especial y cúantica). No utilizamos librerias como numpy, solo math.

# %% [markdown]
# ### **EJERCICIOS**:
#
# $\;$
#
# ### **1. Coordenadas polares y cartesianas:**
# #### Supongamos que se nos da (es decir, el usuario introduce) la posición de un punto en un espacio bidimensional:
#
# #### **a)** Si el punto se especifica  en coordenadas polares $r$,$\theta$. Escribe un programa (en `python` sin usar la biblioteca `numpy`) que calcule e imprima la conversión a coordenadas cartesianas $x$, $y$.

# %%
# Importemos math
import math as mt

# %%
# Definamos las variables que vamos a usar 
r = 1/(2**(1/2)) 
theta = 45 # Este ángulo lo vamosa  convertir a grados, pero esperamos que el usuario ya lo de en grados.
print("Tus coordenadas son r, theta: ", r, theta)
# Out:
# Tus coordenadas son r, theta:  0.7071067811865475 45

# %%
# Convertimos theta a grados
theta = mt.radians(theta) # Revisamos la libreria y este comando hace que pasemos de grados a radianes
x = r*mt.cos(theta)
y = r*mt.sin(theta)

# %%
print("Tus coordenadas son: ", "x = ", (round(x, 4)), "y = ", (round(y, 4)))
# Out:
# Tus coordenadas son:  x =  0.5 y =  0.5

# %%
# Vamos hacerlo función (Esto es fuera de la tarea)
def polares_a_Cartesianas(r,theta):
    theta = mt.radians(theta)
    x = r*mt.cos(theta)
    y = r*mt.sin(theta)

    return print("Tus coordenadas son: ", "x = ", (round(x, 4)), "y = ", (round(y, 4)))

# %%
polares_a_Cartesianas(1/(2**(1/2)), 45)
# Out:
# Tus coordenadas son:  x =  0.5 y =  0.5

# %% [markdown]
# #### **b)** Si el punto se especifica en coordenadas cartesianas $x$, $y$. Escribe un programa (en `python` sin usar `numpy`) que calcule e imprima la conversión a coordenadas polares $r$,$\theta$.

# %%
# Definimos las variables
x   = 0.5 
y = 0.5

# %%
r = mt.sqrt(x**2 + y**2)
theta = mt.degrees(mt.atan((x/y))) # ahora pasamos de radianes a grados

# %%
print("Tus coordenadas son: ", "r = ", (round(r, 4)), "theta = ", (round(theta, 4)))
# Out:
# Tus coordenadas son:  r =  0.7071 theta =  45.0

# %% [markdown]
# ### **2. Caída de una pelota desde una torre:**
# #### Se deja caer una pelota desde una torre de altura $h$. Tiene velocidad inicial cero y acelera hacia abajo con la gravedad.
#
# Escribe un programa que le pida al usuario que ingrese la altura en metros de la torre y luego calcule e imprima el tiempo en segundos hasta que la pelota toque el suelo (ignora la resistencia del aire).
#
# Después, usa tu programa para calcular el tiempo de una pelota lanzada desde una torre de $100m$ de altura.\\

# %%
import math as mt
# Ya se había importado, pero quizás el ayudante decida no ejercutar la celda.

# %%
h = float(input("¿A qué altura te gustaría que caiga (en metros)?"))
g = 9.81 #m/s^2
t_caida = mt.sqrt((2*h)/g)
print("El tiempo de caida en [s] es: ", round(t_caida, 2))
# Out:
# El tiempo de caida en [s] es:  4.52

# %%
h = 100 # Si la altura es de 100 m
g = 9.81 #m/s^2
t_caida = mt.sqrt((2*h)/g)
print("El tiempo de caida en [s] es: ", round(t_caida, 2))
# Out:
# El tiempo de caida en [s] es:  4.52

# %% [markdown]
# ### **3. Relatividad especial:**
# #### Una nave espacial viaja desde la Tierra en línea recta a una velocidad relativista $v$ a otro planeta a $x$ años luz de distancia.
#
# #### Escribe un programa que le pida al usuario el valor de $x$ y la velocidad $v$ como una fracción de la velocidad de la luz $c$, y que imprima el tiempo en años que tarda la nave espacial en llegar a su destino
#
# #### **(a)** en el marco de reposo de un observador en la Tierra y

# %%
x = float(input("Dame la distancia que ha viajado en años luz: "))
v = float(input("Dame la velocidad a la que ha viajado en unidades de la velocidad de la luz: "))
if v >=1 :
    print("Recuerda que nada viaja más rápido que velocidad de la luz")
elif 0<v<1:

    t_tierra = x/v
# sé que no hemos estudiado el comando f"{algo}"
# pero es facil de entender, mete a la variable que quiero y así no tengo que concatenar con comas
# Lo iba usar desde el primer programa, pero pesé que me iban a decir algo, lo voy a ocupar de 
# aquí en adelante
    print(f"El tiempo transcurrido desde la tierra es {t_tierra} años ")
# Out:
# Recuerda que nada viaja más rápido que v

# %% [markdown]
# #### **(b)** como lo percibiría un pasajero a bordo de la nave.

# %%
x = float(input("Dame la distancia que ha viajado en años luz: "))
v = float(input("Dame la velocidad a la que ha viajado en unidades de la velocidad de la luz: "))
if v >=1 :
    print("Recuerda que nada viaja más rápido que la velocidad de la luz")
elif 0<v<1:
    t_nave = (x/v) * mt.sqrt(1-(v**2))
    print(f"El tiempo transcurrido desde la nave es {t_nave} años ")
# Out:
# El tiempo transcurrido desde la nave es 23.24746103221692 años

# %% [markdown]
# #### Usa tu programa para calcular las respuestas para un planeta a 10 años luz de distancia con $v = 0.99c$

# %%
x = 10
v = 0.99
if v >=1 :
    print("Recuerda que nada viaja más rápido que velocidad de la luz")
elif 0<v<1:

    t_tierra = x/v
# sé que no hemos estudiado el comando f"{algo}"
# pero es facil de entender, mete a la variable que quiero y así no tengo que concatenar con comas
# Lo iba usar desde el primer programa, pero pesé que me iban a decir algo, lo voy a ocupar de 
# aquí en adelante
    print(f"El tiempo transcurrido desde la tierra es {t_tierra} años ")
# Out:
# El tiempo transcurrido desde la tierra es 10.1010101010101 años

# %%
x = 10
v = 0.99
if v >=1 :
    print("Recuerda que nada viaja más rápido que la velocidad de la luz")
elif 0<v<1:
    t_nave = (x/v) * mt.sqrt(1-(v**2))
    print(f"El tiempo transcurrido desde la nave es {t_nave} años ")
# Out:
# El tiempo transcurrido desde la nave es 1.424922826228878 años

# %% [markdown]
# ### **4. Paso de potencial cuántico.**
#
# #### Un conocido problema de mecánica cuántica involucra una partícula de masa $m$ que encuentra un paso de potencial unidimensional, como este:
#
# <center><img src="qstep2.png" width="50%" class="center"/></center>
#
# #### La partícula con energía cinética inicial $E$ y vector de onda $k_1=\sqrt{2mE}/\hbar$ entra por la izquierda y encuentra un salto repentino en la energía potencial de altura $V$ en la posición $x=0$. Resolviendo la ecuación de Schrödinger, se puede demostrar que cuando $E>V$ la partícula puede
#
# #### (a) **pasar el escalón**, en cuyo caso tiene una energía cinética menor a $E-V$ en el otro lado y un vector de onda correspondientemente menor a $k_2=\sqrt{2m(E-V)}/\hbar$; o bien (b) **reflejarse**, manteniendo toda su energía cinética y un vector de onda sin cambios, pero moviéndose en la dirección opuesta. Las probabilidades $T$ y $R$ de transmisión y reflexión están dadas por:
#
# $$T=\frac{4k_1k_2}{(k_1+k_2)^2},\qquad R=\left(\frac{k_1-k_2}{k_1+k_2}\right)^2.$$
#
# #### Supongamos que tenemos una partícula con una masa igual a la masa del electrón, $m=9.11\times10^{-31}\,\mathrm{kg}$, y energía de $10\,\mathrm{eV}$, al encontrar un escalón de potencial de altura $9\,\mathrm{eV}$. Escribe un programa en `Python` para calcular e imprimir las probabilidades de transmisión y reflexión utilizando las fórmulas anteriores.

# %%
# Vamos a definir las variables 
m = 9.11e-31 # kg
E = 10 * 1.602176634e-19  # j
V = 9 * 1.602176634e-19  # j
h_barra = 1.054571817e-34  # J*s

# %%
# Vamos a calcular k_1 y k_2

k_1 = mt.sqrt(2*m*E)/h_barra

k_2 = mt.sqrt(2*m*(E-V))/h_barra

print(f"Los valores de k_1 es {k_1} [m^-1], y k_2 es {k_2} [m^-1]")
# Out:
# Los valores de k_1 es 16201425286.715166 [m^-1], y k_2 es 5123340524.706647 [m^-1]

# %%
# Para la transmitacia tenemos 
T = (4*k_1*k_2)/ ((k_1+k_2)**2)
# Para la reflexión
R = ((k_1-k_2)/(k_1+k_2))**2
print(f"la probabilidad de la transmisión es {T}")
print(f"la probabilidad de la reflexión es {R}")
# Out:
# la probabilidad de la transmisión es 0.7301261363877617
# la probabilidad de la reflexión es 0.26987386361223814

# %%
print(T + R)
# Out:
# 0.9999999999999998
